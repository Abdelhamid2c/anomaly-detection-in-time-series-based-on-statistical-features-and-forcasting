# %% [markdown]
# # Forcasting with LSTM on NGA time serie

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
path_1 = '../Data/test_st.csv'
path_2 = '../Data/extaction_missing_data.csv'
path_saved_models = "../saved_models/model_nga_Last.keras"

# %%
df = pd.read_csv(path_1)
df.index = pd.to_datetime(df['value_created_at'])

df.sample(6)
# Out:
#                         value_created_at  measure_id  point_id      NGA  \
# value_created_at
# 2023-10-05 16:40:00  2023-10-05 16:40:00    15206947    232710  3.67861
# 2024-01-17 17:40:00  2024-01-17 17:40:00    19417667    232710  0.48696
# 2023-08-22 17:40:00  2023-08-22 17:40:00    14217181    232710  1.01328
# 2024-02-02 14:40:00  2024-02-02 14:40:00    20049804    232710  0.40435
# 2023-09-04 21:40:00  2023-09-04 21:40:00    14471057    232710  1.21680
# 2023-11-15 17:40:00  2023-11-15 17:40:00    16421993    232710  6.62478
#
#                           NGV         K      VCC_g      VC_g
# value_created_at
# 2023-10-05 16:40:00  11.59791  5.366681   69.12497  37.13800
# 2024-01-17 17:40:00   4.71101  3.209693    6.55221   3.72410
# 2023-08-22 17:40:00   7.32233  5.387333   14.68381   8.24414
# 2024-02-02 14:40:00   3.83427  3.214648    4.03272   2.33467
# 2023-09-04 21:40:00   8.10987  9.543598   26.12523  13.11276
# 2023-11-15 17:40:00  10.31961  9.103568  153.10270  87.25179

# %%
nga = df[['NGA']]

# %%
from tensorflow.keras.models import load_model
model1 = load_model(path_saved_models)

# %%
prediction = model1.predict(nga.NGA.values[-382:].reshape((-1, 382, 1)))
prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# array([[0.51850927]], dtype=float32)

# %%
last_timestamp = nga.index[-1]

new_timestamp = last_timestamp + pd.Timedelta(hours=1)

new_row = pd.DataFrame({'value_created_at': [new_timestamp], 'NGA': [455]})
new_row.set_index('value_created_at', inplace=True)
nga = pd.concat([nga, new_row], ignore_index=False)

nga
# Out:
#                            NGA
# value_created_at
# 2023-06-24 15:05:48    0.10832
# 2023-06-24 15:22:51    0.10783
# 2023-06-24 15:50:00    0.10815
# 2023-06-24 15:55:00    0.10708
# 2023-06-24 16:00:00    0.10750
# ...                        ...
# 2024-03-01 07:40:00    0.52915
# 2024-03-01 08:40:00    0.55540
# 2024-03-01 09:40:00    0.50074
# 2024-03-01 10:40:00    0.50810
# 2024-03-01 11:40:00  455.00000
#
# [5705 rows x 1 columns]

# %%
nga.NGA.values[-382:].reshape((-1, 382, 1))
# Out:
# array([[[4.82960e-01],
#         [4.72850e-01],
#         [4.55330e-01],
#         [5.72630e-01],
#         [4.83620e-01],
#         [4.96770e-01],
#         [4.37090e-01],
#         [4.49090e-01],
#         [4.48830e-01],
#         [4.88570e-01],
#         [5.23660e-01],
#         [4.61210e-01],
#         [5.25240e-01],
#         [4.76100e-01],
#         [4.67850e-01],
#         [4.59720e-01],
#         [4.96650e-01],
#         [4.49260e-01],
#         [5.17640e-01],
#         [5.27890e-01],
#         [5.46080e-01],
#         [5.49270e-01],
#         [5.29150e-01],
#         [5.55400e-01],
#         [5.00740e-01],
#         [5.08100e-01],
#         [4.55000e+02]]])

# %%
def run_model(df,periods = 1):
    df['value_created_at'] = pd.to_datetime(df['value_created_at'])
    df.set_index('value_created_at', inplace=True)
    nga = df[['NGA']]
    nga['set'] = 'actual'
    model1 = load_model(path_saved_models)
    for period in range(periods) :
        prediction = model1.predict(nga.NGA.values[-382:].reshape((-1,382,1)))
        last_timestamp = nga.index[-1]
        new_timestamp = last_timestamp + pd.Timedelta(hours=1)
        new_row = pd.DataFrame({'value_created_at': [new_timestamp], 'NGA': [prediction[0][0]]})
        new_row['set'] = 'predicted'
        new_row.set_index('value_created_at', inplace=True)
        nga = pd.concat([nga, new_row], ignore_index=False)
    return nga

# %%
df = pd.read_csv(path_1)
df
# Out:
#          value_created_at  measure_id  point_id      NGA      NGV         K  \
# 0     2023-06-24 15:05:48    12870679    232710  0.10832  2.77359  1.891347
# 1     2023-06-24 15:22:51    12870678    232710  0.10783  3.13995  1.896530
# 2     2023-06-24 15:50:00    12870677    232710  0.10815  2.66659  1.887733
# 3     2023-06-24 15:55:00    12870676    232710  0.10708  2.65100  1.901864
# 4     2023-06-24 16:00:00    12870675    232710  0.10750  2.55173  1.898690
# ...                   ...         ...       ...      ...      ...       ...
# 5699  2024-03-01 06:40:00    21130040    232710  0.54927  4.42352  4.068230
# 5700  2024-03-01 07:40:00    21132241    232710  0.52915  4.16160  4.259252
# 5701  2024-03-01 08:40:00    21134403    232710  0.55540  4.46625  4.059374
# 5702  2024-03-01 09:40:00    21136658    232710  0.50074  4.34932  4.110944
# 5703  2024-03-01 10:40:00    21138147    232710  0.50810  4.34101  5.684870
#
#          VCC_g     VC_g
# 0      0.49635  0.41004
# 1      0.48180  0.42522
# 2      0.48101  0.40710
# 3      0.48632  0.40771
# 4      0.49191  0.42289
# ...        ...      ...
# 5699   9.18245  4.87565
# 5700   8.98788  5.14323
# 5701   8.60813  4.33526
# 5702   7.49714  3.75781
# 5703  10.26147  5.13945
#
# [5704 rows x 8 columns]

# %%
results = run_model(df, 10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_17284\4017140374.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nga['set'] = 'actual'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step

# %%
results[results['set'] == 'predicted']
# Out:
#                           NGA        set
# value_created_at
# 2024-03-01 11:40:00  0.518509  predicted
# 2024-03-01 12:40:00  0.515477  predicted
# 2024-03-01 13:40:00  0.512416  predicted
# 2024-03-01 14:40:00  0.509439  predicted
# 2024-03-01 15:40:00  0.506541  predicted
# 2024-03-01 16:40:00  0.503716  predicted
# 2024-03-01 17:40:00  0.500956  predicted
# 2024-03-01 18:40:00  0.498255  predicted
# 2024-03-01 19:40:00  0.495609  predicted
# 2024-03-01 20:40:00  0.493014  predicted
