# %% [markdown]
# # Forcasting with LSTM on NGA time serie

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
path_1 = "../Data/test_st.csv"
path_2 = "../Data/extaction_missing_data.csv"

df = pd.read_csv(path_1)
#df2 = pd.read_csv(path_2)

# %%
df
# Out:
#          value_created_at  measure_id  point_id      NGA      NGV         K  \
# 0     2023-06-24 15:05:48    12870679    232710  0.10832  2.77359  1.891347
# 1     2023-06-24 15:22:51    12870678    232710  0.10783  3.13995  1.896530
# 2     2023-06-24 15:50:00    12870677    232710  0.10815  2.66659  1.887733
# 3     2023-06-24 15:55:00    12870676    232710  0.10708  2.65100  1.901864
# 4     2023-06-24 16:00:00    12870675    232710  0.10750  2.55173  1.898690
# ...                   ...         ...       ...      ...      ...       ...
# 5699  2024-03-01 06:40:00    21130040    232710  0.54927  4.42352  4.068230
# 5700  2024-03-01 07:40:00    21132241    232710  0.52915  4.16160  4.259252
# 5701  2024-03-01 08:40:00    21134403    232710  0.55540  4.46625  4.059374
# 5702  2024-03-01 09:40:00    21136658    232710  0.50074  4.34932  4.110944
# 5703  2024-03-01 10:40:00    21138147    232710  0.50810  4.34101  5.684870
#
#          VCC_g     VC_g
# 0      0.49635  0.41004
# 1      0.48180  0.42522
# 2      0.48101  0.40710
# 3      0.48632  0.40771
# 4      0.49191  0.42289
# ...        ...      ...
# 5699   9.18245  4.87565
# 5700   8.98788  5.14323
# 5701   8.60813  4.33526
# 5702   7.49714  3.75781
# 5703  10.26147  5.13945
#
# [5704 rows x 8 columns]

# %%
df2
# Out:
#       Unnamed: 0     value_created_at  measure_id    NGA    NGV         K  \
# 0              0  2022-01-15 21:08:32     4055996  0.230  0.420  0.000000
# 1              1  2022-01-15 21:25:21     4056494  0.230  0.390  0.000000
# 2              2  2022-01-16 01:25:21     4059012  0.240  0.440  0.000000
# 3              3  2022-01-16 05:25:21     4061956  0.240  0.420  0.000000
# 4              4  2022-01-16 09:25:21     4064764  0.240  0.430  0.000000
# ...          ...                  ...         ...    ...    ...       ...
# 9729        9729  2024-08-12 22:57:28    28098744  0.413  0.471  4.117731
# 9730        9730  2024-08-13 00:57:28    28102034  0.410  0.500  4.170659
# 9731        9731  2024-08-13 02:57:28    28105174  0.418  0.508  4.137773
# 9732        9732  2024-08-13 04:57:28    28108468  0.415  0.532  4.069019
# 9733        9733  2024-08-13 06:57:28    28111699  0.416  0.482  4.229354
#
#          VCC_g      VC_g
# 0     0.000000  0.000000
# 1     0.000000  0.000000
# 2     0.000000  0.000000
# 3     0.000000  0.000000
# 4     0.000000  0.000000
# ...        ...       ...
# 9729  5.701956  2.880685
# 9730  5.707357  3.037322
# 9731  5.385080  2.833874
# 9732  5.228443  2.776260
# 9733  6.026033  3.040923
#
# [9734 rows x 8 columns]

# %%
df.index = pd.to_datetime(df['value_created_at'])
df2.index = pd.to_datetime(df2['value_created_at'])

# %%
df
# Out:
#                         value_created_at  measure_id  point_id      NGA  \
# value_created_at
# ...                    ...       ...       ...       ...
# 2024-08-12 22:57:28  0.471  4.117731  5.701956  2.880685
# 2024-08-13 00:57:28  0.500  4.170659  5.707357  3.037322
# 2024-08-13 02:57:28  0.508  4.137773  5.385080  2.833874
# 2024-08-13 04:57:28  0.532  4.069019  5.228443  2.776260
# 2024-08-13 06:57:28  0.482  4.229354  6.026033  3.040923
#
# [9734 rows x 8 columns]

# %%
nga = df['NGA']
nga2 = df2['NGA']

# %%
fig, ax = plt.subplots(figsize=(20, 5))
nga.plot();

# %%
fig, ax = plt.subplots(figsize=(20, 5))
nga2.plot();

# %%
nga.index
# Out:
# DatetimeIndex(['2023-06-24 15:05:48', '2023-06-24 15:22:51',
#                '2023-06-24 15:50:00', '2023-06-24 15:55:00',
#                '2023-06-24 16:00:00', '2023-06-24 16:05:00',
#                '2023-06-24 16:10:00', '2023-06-24 16:20:00',
#                '2023-06-24 16:30:00', '2023-07-07 20:37:52',
#                ...
#                '2024-03-01 01:40:00', '2024-03-01 02:40:00',
#                '2024-03-01 03:40:00', '2024-03-01 04:40:00',
#                '2024-03-01 05:40:00', '2024-03-01 06:40:00',
#                '2024-03-01 07:40:00', '2024-03-01 08:40:00',
#                '2024-03-01 09:40:00', '2024-03-01 10:40:00'],
#               dtype='datetime64[ns]', name='value_created_at', length=5704, freq=None)

# %%
nga2.index
# Out:
# DatetimeIndex(['2022-01-15 21:08:32', '2022-01-15 21:25:21',
#                '2022-01-16 01:25:21', '2022-01-16 05:25:21',
#                '2022-01-16 09:25:21', '2022-01-16 13:25:21',
#                '2022-01-16 17:25:21', '2022-01-16 21:25:21',
#                '2022-01-17 01:25:21', '2022-01-17 05:25:21',
#                ...
#                '2024-08-12 15:24:56', '2024-08-12 16:57:27',
#                '2024-08-12 17:02:31', '2024-08-12 18:57:28',
#                '2024-08-12 20:57:28', '2024-08-12 22:57:28',
#                '2024-08-13 00:57:28', '2024-08-13 02:57:28',
#                '2024-08-13 04:57:28', '2024-08-13 06:57:28'],
#               dtype='datetime64[ns]', name='value_created_at', length=9734, freq=None)

# %%
diff = np.diff(nga.index)/1e9
diff = diff.astype(np.int32)
diff
# Out:
# array([1023, 1629,  300, ..., 3600, 3600, 3600])

# %%
diff2 = np.diff(nga2.index)/1e9
diff2 = diff2.astype(np.int32)
diff2
# Out:
# array([ 1009, 14400, 14400, ...,  7200,  7200,  7200])

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(diff)
plt.scatter(x=np.where(diff!=3600), y=diff[diff!=3600], color='red')

# %%
fig, ax = plt.subplots(figsize=(20, 5))
#plt.plot(diff2)
#plt.scatter(x=np.where(diff2!=3600), y=diff2[diff2!=3600], color='red')
plt.scatter(x=np.array(range(len(diff2))), y=diff2)
plt.ylim([3000, 8000])
# Out:
# (3000.0, 8000.0)

# %%
np.median(diff2)
# Out:
# 5400.0

# %% [markdown]
# <b>Remarks:</b>
# - From the above plot we can see that not all points are 1-hour separated
# - And inconsistencies are occuring everywhere
# - Thus, we cannot have sufficient interval with 1-hour separated points
# - A possible solution is make an interpolation with available points, then sample every 1 hour from the interpolation

# %%
def df_to_X_y(df, window_size=5, delay=1):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size-delay+1):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size+delay-1]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 369
DELAY = 24
X, y = df_to_X_y(nga, WINDOW_SIZE, DELAY)
X.shape, y.shape
# Out:
# ((5312, 369, 1), (5312,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.55, shuffle=False)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((1912, 369, 1), (1912,), (478, 369, 1), (478,), (2922, 369, 1), (2922,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError, MAE
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam, SGD

model1 = Sequential()
model1.add(InputLayer((WINDOW_SIZE, 1)))
model1.add(LSTM(29,
           dropout=0.3800180130212968,
           recurrent_dropout=0.8939575779772313))
model1.add(Dense(18, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 29)             │         3,596 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 18)             │           540 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            19 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,155 (16.23 KB)
#  Trainable params: 4,155 (16.23 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('model_nga_1day.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.00043266386333))

# %%
history = model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - loss: 3.0072 - val_loss: 4.9458
# Epoch 2/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - loss: 2.3085 - val_loss: 2.4516
# Epoch 3/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - loss: 1.9759 - val_loss: 1.2637
# Epoch 4/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - loss: 1.6645 - val_loss: 0.7038
# Epoch 5/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - loss: 1.6585 - val_loss: 0.4959
# Epoch 6/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - loss: 1.5366 - val_loss: 0.3698
# Epoch 7/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - loss: 1.4037 - val_loss: 0.2681
# Epoch 8/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - loss: 1.3981 - val_loss: 0.2153
# Epoch 9/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 7s 123ms/step - loss: 1.6234 - val_loss: 0.2241
# Epoch 10/10
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 8s 125ms/step - loss: 1.4072 - val_loss: 0.1743

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model_nga_1day.keras')

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train})
train_results
# Out:
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
#       Train Predictions  Actuals
# 0              0.884239  0.48824
# 1              0.884182  0.49555
# 2              0.884540  0.51136
# 3              0.884357  0.48270
# 4              0.884893  0.51272
# ...                 ...      ...
# 1907           4.819810  7.48536
# 1908           4.797438  7.48393
# 1909           4.764246  7.30606
# 1910           4.777352  7.47846
# 1911           4.808613  7.35517
#
# [1912 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(train_results['Train Predictions'])
plt.plot(train_results['Actuals'])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val})
val_results
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
#      Val Predictions  Actuals
# 0           4.798932  7.34947
# 1           4.808105  7.08627
# 2           4.811689  6.65572
# 3           4.857343  6.31880
# 4           4.847844  6.15319
# ..               ...      ...
# 473         3.288911  3.48110
# 474         3.234938  3.52392
# 475         3.298592  4.18767
# 476         3.417470  3.44115
# 477         3.375924  3.64453
#
# [478 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(val_results['Val Predictions'])
plt.plot(val_results['Actuals'])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})
test_results
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step
#       Test Predictions  Actuals
# 0             3.401650  3.57837
# 1             3.384349  3.80343
# 2             3.355679  3.45282
# 3             3.206468  3.41097
# 4             3.173478  4.60596
# ...                ...      ...
# 2917          0.948646  0.54927
# 2918          0.926147  0.52915
# 2919          0.911851  0.55540
# 2920          0.900644  0.50074
# 2921          0.899478  0.50810
#
# [2922 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 5))
plt.plot(test_results['Test Predictions'])
plt.plot(test_results['Actuals'], linewidth=2, alpha=0.3, color='red')

# %%
from sklearn.metrics import root_mean_squared_error, mean_absolute_error
print("Test RMSE : ", root_mean_squared_error(y_test, test_predictions))
print("Test MAE : ", mean_absolute_error(y_test, test_predictions))
# Out:
# Test RMSE :  0.7638203534543156
# Test MAE :  0.5453595156773797
